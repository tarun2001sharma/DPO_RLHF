# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets

# %%
# !pip install trl

# %%
# !pip install -U "huggingface_hub[cli]"

# %%
# !huggingface-cli login

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

def load_and_extract_articles(file_path):
    # Load the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Data structure to hold the articles and highlights
    articles_data = []

    # Extract the first two articles and highlights
    for entry in data['rows'][:100]:  # Limit to first two entries
        article_entry = {
            "id": entry['row']['id'],
            "article": entry['row']['article'],
            "highlights": entry['row']['highlights']
        }
        articles_data.append(article_entry)

    return articles_data

# Example usage:
file_path = '/content/drive/MyDrive/ConceptualGapsInML/cnn/test_data_cnn.json'
output_path = '/content/drive/MyDrive/ConceptualGapsInML/cnn/cnn_summary_prompts.json'
cnn_test_data = load_and_extract_articles(file_path)


def formatting_prompts_func_3(example):
    bos_token = "<s>"
    text = ""
    text += bos_token
    text += f"Article: {example['article']}\nTL;DR:"
    return text


formatted_prompts = []
for article in cnn_test_data:
  prompt = formatting_prompts_func_3(article)
  formatted_prompts.append(prompt)

with open(output_path, 'w') as file:
  json.dump(formatted_prompts, file, indent=4)

# %%
# Model

print("Loading Model\n")

from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

nf4_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    # "/content/drive/MyDrive/ConceptualGapsProject/huggingFace",
    "mistralai/Mistral-7B-v0.1",
    cache_dir = "/content/mistral_weights/",
    device_map='auto',
    quantization_config=nf4_config,
    use_cache=True,
    trust_remote_code=True,
)
# Out:
# Loading Model
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
# Tokenizer
print("Loading Tokenizer\n")

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1", trust_remote_code=True,)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
# Out:
# Loading Tokenizer
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
# Loading PEFT Model and save the summary results to output file

from peft import PeftModel
from tqdm import tqdm
import json

sft_model_3 = PeftModel.from_pretrained(model, "/content/drive/MyDrive/ConceptualGapsInML/SFT_Model_3/SFT_Model_3/checkpoint-10000/")

def extract_after_tldr(text):
    index = text.find("TL;DR:")

    if index != -1:
        return text[index + len("TL;DR:"):].strip()
    else:
        return text

def respond(query):
    model_input_3 = tokenizer(query, return_tensors="pt").to("cuda")
    output_3 = tokenizer.decode(sft_model_3.generate(**model_input_3, max_new_tokens=256, repetition_penalty=1.15)[0], skip_special_tokens=True)
    return output_3

output_file = "/content/drive/MyDrive/ConceptualGapsInML/cnn/SFT_Summaries_cnn.jsonl"
input_file = "/content/drive/MyDrive/ConceptualGapsInML/cnn/cnn_summary_prompts.json"

from datasets import load_dataset
cnn_summary_prompts = load_dataset("json", data_files=input_file, split="train")
cnn_summaries = []

with open(output_file, 'w') as file:
  for i in tqdm(range(100), "Processing"):
    response = respond(cnn_summary_prompts[i]['text'])
    response = extract_after_tldr(response)
    cnn_summaries.append(response)
    json.dump({'summary': response}, file)
    file.write('\n')

print(f"Output written to {output_file}")
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   1%|          | 1/100 [00:07<12:13,  7.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   2%|▏         | 2/100 [00:12<10:12,  6.25s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   3%|▎         | 3/100 [00:22<12:19,  7.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   4%|▍         | 4/100 [00:26<10:05,  6.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   5%|▌         | 5/100 [00:31<09:33,  6.03s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   6%|▌         | 6/100 [00:38<09:46,  6.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   7%|▋         | 7/100 [00:49<11:51,  7.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   8%|▊         | 8/100 [00:54<10:50,  7.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:   9%|▉         | 9/100 [01:00<09:48,  6.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  10%|█         | 10/100 [01:03<08:17,  5.53s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  11%|█         | 11/100 [01:06<06:53,  4.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  12%|█▏        | 12/100 [01:13<07:47,  5.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  13%|█▎        | 13/100 [01:19<08:05,  5.58s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  14%|█▍        | 14/100 [01:29<10:08,  7.08s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  15%|█▌        | 15/100 [01:35<09:15,  6.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  16%|█▌        | 16/100 [01:46<11:07,  7.94s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  17%|█▋        | 17/100 [01:55<11:37,  8.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  18%|█▊        | 18/100 [02:08<13:15,  9.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  19%|█▉        | 19/100 [02:17<13:01,  9.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  20%|██        | 20/100 [02:23<11:18,  8.48s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  21%|██        | 21/100 [02:34<12:06,  9.19s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  22%|██▏       | 22/100 [02:44<12:08,  9.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  23%|██▎       | 23/100 [02:54<12:27,  9.71s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  24%|██▍       | 24/100 [02:59<10:25,  8.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  25%|██▌       | 25/100 [03:04<08:56,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  26%|██▌       | 26/100 [03:15<10:28,  8.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  27%|██▋       | 27/100 [03:20<09:05,  7.48s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  28%|██▊       | 28/100 [03:32<10:33,  8.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  29%|██▉       | 29/100 [03:41<10:20,  8.74s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  30%|███       | 30/100 [03:51<10:33,  9.06s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  31%|███       | 31/100 [03:57<09:35,  8.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  32%|███▏      | 32/100 [04:13<11:59, 10.58s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  33%|███▎      | 33/100 [04:22<11:09,  9.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  34%|███▍      | 34/100 [04:28<09:47,  8.90s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  35%|███▌      | 35/100 [04:34<08:36,  7.95s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  36%|███▌      | 36/100 [04:43<08:55,  8.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  37%|███▋      | 37/100 [04:55<09:58,  9.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  38%|███▊      | 38/100 [05:09<10:57, 10.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  39%|███▉      | 39/100 [05:16<09:50,  9.68s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  40%|████      | 40/100 [05:36<12:45, 12.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  41%|████      | 41/100 [05:41<10:12, 10.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  42%|████▏     | 42/100 [05:57<11:35, 11.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  43%|████▎     | 43/100 [06:02<09:28,  9.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  44%|████▍     | 44/100 [06:08<08:17,  8.88s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  45%|████▌     | 45/100 [06:18<08:17,  9.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  46%|████▌     | 46/100 [06:22<06:50,  7.61s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  47%|████▋     | 47/100 [06:29<06:29,  7.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  48%|████▊     | 48/100 [06:40<07:24,  8.55s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  49%|████▉     | 49/100 [06:48<07:10,  8.44s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  50%|█████     | 50/100 [06:55<06:32,  7.86s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  51%|█████     | 51/100 [07:06<07:10,  8.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  52%|█████▏    | 52/100 [07:15<07:09,  8.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  53%|█████▎    | 53/100 [07:23<06:44,  8.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  54%|█████▍    | 54/100 [07:31<06:26,  8.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  55%|█████▌    | 55/100 [07:42<06:55,  9.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  56%|█████▌    | 56/100 [07:47<05:51,  7.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  57%|█████▋    | 57/100 [07:52<04:59,  6.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  58%|█████▊    | 58/100 [08:00<05:11,  7.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  59%|█████▉    | 59/100 [08:09<05:23,  7.89s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  60%|██████    | 60/100 [08:16<05:08,  7.72s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  61%|██████    | 61/100 [08:26<05:26,  8.37s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  62%|██████▏   | 62/100 [08:40<06:15,  9.87s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  63%|██████▎   | 63/100 [08:44<05:01,  8.15s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  64%|██████▍   | 64/100 [08:48<04:09,  6.94s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  65%|██████▌   | 65/100 [08:53<03:47,  6.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  66%|██████▌   | 66/100 [08:57<03:11,  5.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  67%|██████▋   | 67/100 [09:07<03:50,  6.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  68%|██████▊   | 68/100 [09:13<03:31,  6.62s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  69%|██████▉   | 69/100 [09:18<03:13,  6.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  70%|███████   | 70/100 [09:24<03:02,  6.09s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  71%|███████   | 71/100 [09:29<02:46,  5.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  72%|███████▏  | 72/100 [09:35<02:42,  5.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  73%|███████▎  | 73/100 [09:46<03:21,  7.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  74%|███████▍  | 74/100 [09:57<03:40,  8.46s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  75%|███████▌  | 75/100 [10:01<02:57,  7.08s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  76%|███████▌  | 76/100 [10:08<02:52,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  77%|███████▋  | 77/100 [10:15<02:41,  7.03s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  78%|███████▊  | 78/100 [10:24<02:50,  7.76s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  79%|███████▉  | 79/100 [10:38<03:22,  9.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  80%|████████  | 80/100 [10:42<02:38,  7.92s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  81%|████████  | 81/100 [10:55<02:56,  9.29s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  82%|████████▏ | 82/100 [11:02<02:34,  8.56s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  83%|████████▎ | 83/100 [11:12<02:32,  8.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  84%|████████▍ | 84/100 [11:17<02:05,  7.83s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  85%|████████▌ | 85/100 [11:21<01:39,  6.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  86%|████████▌ | 86/100 [11:33<01:57,  8.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  87%|████████▋ | 87/100 [11:38<01:34,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  88%|████████▊ | 88/100 [11:44<01:24,  7.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  89%|████████▉ | 89/100 [11:49<01:11,  6.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  90%|█████████ | 90/100 [11:54<00:59,  5.92s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  91%|█████████ | 91/100 [11:58<00:46,  5.20s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  92%|█████████▏| 92/100 [12:04<00:45,  5.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  93%|█████████▎| 93/100 [12:14<00:47,  6.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  94%|█████████▍| 94/100 [12:23<00:45,  7.55s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  95%|█████████▌| 95/100 [12:29<00:35,  7.14s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  96%|█████████▌| 96/100 [12:42<00:35,  8.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  97%|█████████▋| 97/100 [12:47<00:23,  7.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  98%|█████████▊| 98/100 [12:53<00:14,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing:  99%|█████████▉| 99/100 [13:05<00:08,  8.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing: 100%|██████████| 100/100 [13:11<00:00,  7.91s/it]
# Output written to /content/drive/MyDrive/ConceptualGapsInML/cnn/SFT_Summaries_cnn.jsonl

# %%
# Generate the prompts to ask GPT

from datasets import load_dataset

SFT_summaries_cnn = load_dataset("json", data_files="/content/drive/MyDrive/ConceptualGapsInML/cnn/SFT_Summaries_cnn.jsonl", split="train")

def create_gpt4_prompt(post, summary_a, summary_b):
    prompt_text = f"""
system
You are a helpful assistant, that ranks models by the quality of their answers.

user
Which of the following summaries does a better job of summarizing the most important points in the given forum post, without including unimportant or irrelevant details? A good summary is both precise and concise.
Post: "{post}"
Summary A:
{{
"model": "Mistral7b_SFT",
"summary": "{summary_a}"
}}
Summary B:
{{
"model": "Original",
"summary": "{summary_b}"
}}
Now please rank the models by the quality of their summaries, so that the model with rank 1 has the best summary. Then return a list of the model names and ranks, i.e., produce the following output:
[
{{'model': <model-name>, 'rank': <model-rank>}},
{{'model': <model-name>, 'rank': <model-rank>}}
]
Your response must be a valid Python dictionary and should contain nothing else because we will directly execute it in Python. Please provide the ranking that the majority of humans would give.
"""
    return prompt_text


output_file = "/content/drive/MyDrive/ConceptualGapsInML/cnn/cnn_gpt4_prompts_summary.jsonl"


with open(output_file, 'w') as f:
  for i in tqdm(range(100), desc="Processing queries"):
      prompt = create_gpt4_prompt(cnn_test_data[i]['article'], SFT_summaries_cnn[i]['summary'], cnn_test_data[i]['highlights'])
      json.dump({'prompt': prompt}, f)
      f.write('\n')

print(f"Prompts written to {output_file}")
# Out:
# Processing queries: 100%|██████████| 100/100 [00:00<00:00, 6786.46it/s]
# Prompts written to /content/drive/MyDrive/ConceptualGapsInML/cnn/cnn_gpt4_prompts_summary.jsonl

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.24.0-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.1)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.24.0

# %%
#Call GPT-4 on the prompts and save the data

import os
from openai import OpenAI
import json

os.environ["OPENAI_API_KEY"]

client = OpenAI(api_key=os.environ['OPENAI_API_KEY'])

def callGPT4(prompt):
  response = client.chat.completions.create(
              model="gpt-4",
              messages=[
                  {"role": "system", "content": "You are a helpful assistant, that ranks models by the quality of their answers."},
                  {"role": "user", "content": prompt}
              ]
          )
  return response.choices[0].message.content

GPT4_prompts = load_dataset("json", data_files="/content/drive/MyDrive/ConceptualGapsInML/cnn/cnn_gpt4_prompts_summary.jsonl", split="train")

output_file = "/content/drive/MyDrive/ConceptualGapsInML/cnn/GPT4Responses_Generalization_cnn.jsonl"

def extract_after_user(text):
    index = text.find("user")

    if index != -1:
        return text[index + len("user"):].strip()
    else:
        return text

with open(output_file, 'w') as f:
  for i in tqdm(range(100), desc="Calling GPT4"):
    prompt = extract_after_user(GPT4_prompts[i]['prompt'])
    response = callGPT4(prompt)
    json.dump({'response': response}, f)
    f.write('\n')

print(f"Prompts written to {output_file}")
# Out:
# Calling GPT4: 100%|██████████| 100/100 [09:02<00:00,  5.43s/it]
# Prompts written to /content/drive/MyDrive/ConceptualGapsInML/cnn/GPT4Responses_Generalization_cnn.jsonl
